# %% [markdown]
# ### Different optimisers

# %%
# Imports
from train import train_model
from models import *

# %%
# Values set from the Gatys paper 
alpha, beta = 1, 0.0001
weights = {'conv1_1': 0.2, 'conv2_1': 0.2, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
style_path = "data/style_images/starry.jpg"
content_path = "data/content_images/input.png"

# %%
# Changing Optimisers
optimisers = ['Adam', 'Adagrad', 'SGD', 'LBFGS']
for opt in optimisers:
    train_model(style_path, content_path, alpha, beta, 1, 1, 1000, weights, optimiser = opt)
