# %% [markdown]
# #### Scaling style image

# %%
# Imports
from train import train_model
from models import *

# %%
# Values set from the Gatys paper 
alpha, beta = 1, 0.0001
weights = {'conv1_1': 0.2, 'conv2_1': 0.2, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
style_path = "data/style_images/candy.jpg"
content_path = "data/content_images/input.png"

# %%
# Values set from the Gatys paper | Resize images
scale_percent_list = [10, 30, 60,100]
for scale_percent_ in scale_percent_list:
    train_model(style_path, content_path, alpha, beta, 1, 0, 1000, weights, optimiser = 'Adam', avg_flag = 1, scale_percent = scale_percent_)
