# %% [markdown]
# #### Rotate style image

# %%
# Imports
from train import train_model
from models import *

# %%
# Values set from the Gatys paper 
alpha, beta = 1, 0.0001
weights = {'conv1_1': 0.2, 'conv2_1': 0.2, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
style_path = "data/style_images/starry.jpg"
content_path = "data/content_images/geisel.jpg"

# %%
# Values set from the Gatys paper | Rotate images
rotate_angle_list = [0, 30, 60, 90, 135, 180]
for rotate_percent in rotate_angle_list:
    train_model(style_path, content_path, alpha, beta, 1, 0, 1000, weights, optimiser = 'LBFGS', avg_flag = 1, rotate_percent = rotate_percent)
