# %% [markdown]
# ### Average Pooling

# %%
# Imports
from train import train_model
from models import *
import torch

# %%
# Values set from the Gatys paper 
alpha, beta = 1, 0.0001
weights = {'conv1_1': 0.2, 'conv2_1': 0.2, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
style_path = "data/style_images/mosaic.jpg"
content_path = "data/content_images/amber.jpg"

# %%
# Maxpool vs AvgPool
torch.cuda.empty_cache()
train_model(style_path, content_path, alpha, beta, 1, 0, 1000, weights, avg_flag = 0)
train_model(style_path, content_path, alpha, beta, 1, 0, 1000, weights, avg_flag = 1)
