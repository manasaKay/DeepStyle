# %% [markdown]
# #### 3.1.10 Video

# %%
# Imports
from train import train_model
from models import *

# %%
# Values set from the Gatys paper 
alpha, beta = 0.01, 0.001
weights = {'conv1_1': 0.2, 'conv2_1': 0.2, 'conv3_1': 0.2, 'conv4_1': 0.2, 'conv5_1': 0.2}
style_path = "data/style_images/candy.jpg"

# %%
# Values set from the Gatys paper | Video frames
content_paths = ["data/frames/frame116.jpg","data/frames/frame136.jpg","data/frames/frame96.jpg"]
for content_path in content_paths:
    train_model(style_path, content_path, alpha, beta, 1, 0, 500, weights)
